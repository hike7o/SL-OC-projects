# %% [markdown]
# <h1><center>P7 - CREATE & IMPLEMENT A CREDIT SCORING MODEL</center></h1>

# %% [markdown]
# <div style="width:100%;text-align: center;"> <img align=middle src="http://www.financialbuzz.co.uk/wp-content/uploads/2012/04/Loans-For-Bad-Credit.jpg" alt="Heat beating" style="height:400px;margin-top:3rem;"> </div>

# %% [markdown]
# ## Part 4 - Data preparation for Dashboard

# %% [markdown]
# ## Table of Contents
#
# * [1. Dataset Importation](#chapter1)
#     * [1.1 Full model](#section_1_1)
#     * [1.2 Selected Features model (via BorutaPy)](#section_1_2)
# * [2. Models comparison](#chapter2)
#     * [2.1 Overview](#section_2_1)
#     * [2.2 LightGBM](#section_2_2)
#     * [2.3 XGBoost](#section_2_3)
#     * [2.4 CatBoost](#section_2_4)

# %%
# ! usr/bin/env python 3
# coding: utf-8

import datetime
import requests
import json
import sys
import time
from datetime import datetime
import warnings
import numpy as np
import pandas as pd
import os
import pickle
from collections import Counter
import warnings

# Visualisation
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import joblib as joblib

# Data pré-processing
import sklearn
from sklearn.preprocessing import StandardScaler
import lightgbm as lgb
from lightgbm import LGBMClassifier
from sklearn.neighbors import KNeighborsClassifier

# Metrics
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, \
                            recall_score, precision_score, matthews_corrcoef, \
                            cohen_kappa_score, fbeta_score, make_scorer, \
                            average_precision_score, log_loss, confusion_matrix, \
                            classification_report
# Interprétation
import shap

# Warnings

from warnings import simplefilter
simplefilter("ignore", category=Warning)
warnings.filterwarnings('ignore')
    
from IPython.core.display import display, HTML

from func_modp7 import*

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Versions
print('Version des librairies utilisées :')

print('Python                : ' + sys.version)
print('NumPy                 : ' + np.version.full_version)
print('Pandas                : ' + pd.__version__)
print('Scikit-learn          : ' + sklearn.__version__)
print('Matplotlib            : ' + matplotlib.__version__)
print('Seaborn               : ' + sns.__version__)
print('Shap                 : ' + shap.__version__)
print('Lightgbm              : ' + lgb.__version__)
# Out:
# Version des librairies utilisées :
# Python                : 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]
# NumPy                 : 1.19.5
# Pandas                : 1.2.4
# Scikit-learn          : 0.23.2
# Matplotlib            : 3.3.4
# Seaborn               : 0.11.1
# Shap                 : 0.40.0
# Lightgbm              : 3.3.2

# %% [markdown]
# All functions run in this notebook can be found at: functions_P7_feat.py

# %%
start_time = datetime.now()

# %% [markdown]
# ## 1. Dataset importation for dashboard<a class="anchor" id="chapter1"></a>

# %%
application_test = pd.read_csv('application_test.csv')
application_test_ltd = application_test.head(2000)
application_test_ltd.to_pickle('./application_test_ltd.pkl')

# %%
application_train = pd.read_csv('application_train.csv')
application_train_ltd = application_train.head(2000)
application_train_ltd.to_pickle('./application_train_ltd.pkl')

# %% [markdown]
# ### 1.1 Selected features model (via BorutaPy)<a class="anchor" id="section_1_2"></a>

# %%
# Load data - Lighter range after Boruta
data_train_boruta = pd.read_pickle("train_data_boruta.pkl")
data_test_boruta = pd.read_pickle("test_data_boruta.pkl")
best_model = joblib.load("final_model_w.pkl")
print("Data train shape is:", data_train_boruta.shape)
print("Data test shape is:", data_test_boruta.shape)
best_model
# Out:
# Data train shape is: (307506, 88)
# Data test shape is: (48744, 87)
# LGBMClassifier(bagging_fraction=0.6000000000000001, bagging_freq=1,
#                feature_fraction=0.9, lambda_l1=40, lambda_l2=20,
#                learning_rate=0.12624129923876112, max_depth=12,
#                min_data_in_leaf=200, min_gain_to_split=0.4518795605436023,
#                n_estimators=10000, num_leaves=1180)

# %%
# Limited dataset for deployment into Heroku due to memory errors
data_test_ltd = data_test_boruta.head(2000)
data_test_ltd
# Out:
#         SK_ID_CURR  NAME_CONTRACT_TYPE  FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 307506      100001                   0             0          135000.0
# 307507      100005                   0             0           99000.0
# 307508      100013                   0             1          202500.0
# 307509      100028                   0             0          315000.0
# 307510      100038                   0             1          180000.0
# ...            ...                 ...           ...               ...
# 309501      114010                   0             0           90000.0
# 309502      114011                   0             0          180000.0
# 309503      114032                   0             1          225000.0
# 309504      114047                   0             0           99000.0
# 309505      114055                   0             1          270000.0
#
#         AMT_CREDIT  NAME_TYPE_SUITE  NAME_INCOME_TYPE  NAME_FAMILY_STATUS  \
# 307506    568800.0                0                 0                   1
# 307507    222768.0                0                 0                   1
# 307508    663264.0               -1                 0                   1
# 307509   1575000.0                0                 0                   1
# 307510    625500.0                0                 0                   1
# ...            ...              ...               ...                 ...
# 309501   1161360.0                0                 3                   1
# 309502    286704.0                0                 1                   1
# 309503   1528200.0                0                 0                   1
# 309504    350415.0                1                 3                   2
# 309505   1047771.0                0                 3                   0
#
#         NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  ...  INS_DBD_MEAN  \
# 307506                  0                    0.018845  ...      8.859375
# 307507                  0                    0.035797  ...     23.671875
# 307508                  0                    0.019104  ...      5.722656
# 307509                  0                    0.026398  ...      3.265625
# 307510                  0                    0.010033  ...     12.250000
# ...                   ...                         ...  ...           ...
# 309501                  0                    0.072510  ...     11.695312
# 309502                  0                    0.007114  ...     12.179688
# 309503                  0                    0.019104  ...     12.906250
# 309504                  0                    0.031342  ...      9.976562
# 309505                  0                    0.035797  ...     13.500000
#
#         INS_LATE_PAYMENT_SUM  INS_36M_DAYS_ENTRY_PAYMENT_MIN  \
# 307506                   4.0                          -840.0
# 307507                   8.0                          -736.0
# 307508                  49.0                         -2704.0
# 307509                  55.0                         -1302.0
# 307510                  12.0                          -802.0
# ...                      ...                             ...
# 309501                  13.0                          -846.0
# 309502                  40.0                         -1295.0
# 309503                  11.0                          -840.0
# 309504                  46.0                         -1233.0
# 309505                   2.0                          -828.0
#
#         INS_36M_AMT_INSTALMENT_MEAN  INS_36M_AMT_PAYMENT_SUM  \
# 307506                 15708.870117             3.499691e+05
# 307507                  6240.205078             5.616184e+04
# 307508                 11124.233398             1.444700e+06
# 307509                  4730.878418             3.506999e+05
# 307510                 11100.337891             1.332040e+05
# ...                             ...                      ...
# 309501                 51262.222656             8.351589e+05
# 309502                 35488.746094             9.581962e+05
# 309503                 15708.870117             3.499691e+05
# 309504                 15319.239258             6.177781e+05
# 309505                 39919.835938             7.983967e+04
#
#         INS_36M_SIGNIFICANT_LATE_PAYMENT_MEAN  INS_60M_LATE_PAYMENT_MEAN  \
# 307506                               0.910645                   1.000000
# 307507                               0.888672                   0.888672
# 307508                               0.226074                   0.316162
# 307509                               0.348389                   0.486816
# 307510                               1.000000                   1.000000
# ...                                       ...                        ...
# 309501                               1.000000                   1.000000
# 309502                               0.852051                   0.909180
# 309503                               0.910645                   0.909180
# 309504                               0.975586                   0.978516
# 309505                               1.000000                   1.000000
#
#         INS_60M_SIGNIFICANT_LATE_PAYMENT_MEAN  \
# 307506                               1.000000
# 307507                               0.888672
# 307508                               0.270996
# 307509                               0.486816
# 307510                               1.000000
# ...                                       ...
# 309501                               1.000000
# 309502                               0.909180
# 309503                               0.902344
# 309504                               0.978516
# 309505                               1.000000
#
#         BUREAU_ACTIVE_CREDIT_TO_INCOME_RATIO  \
# 307506                              6.546875
# 307507                              6.046875
# 307508                              4.632812
# 307509                              2.746094
# 307510                              4.632812
# ...                                      ...
# 309501                              4.632812
# 309502                              5.710938
# 309503                              3.160156
# 309504                              4.632812
# 309505                              2.324219
#
#         CURRENT_TO_APPROVED_CREDIT_MIN_RATIO
# 307506                              0.041809
# 307507                              0.180298
# 307508                              0.036530
# 307509                              0.037781
# 307510                              0.148071
# ...                                      ...
# 309501                              0.166138
# 309502                              0.116211
# 309503                              0.051422
# 309504                              0.059662
# 309505                              0.074524
#
# [2000 rows x 87 columns]

# %%
# Limited dataset for deployment into Heroku due to memory errors
data_train_ltd = data_train_boruta.head(2000)
data_train_ltd.drop('TARGET', axis=1, inplace=True)

# %% [markdown]
# Information bbout the customer to be displayed:
#
# **DAYS_BIRTH**: Age - ok but years instead of days
#
# **CODE_GENDER**: Sexe - To add
#
# **NAME_FAMILY_STATUS**: Family Statut - To add (encoded)
#
# **CNT_CHILDREN**: Number of kids - To add
#
# **NAME_EDUCATION_TYPE**: Education Type - To add
#
# **NAME_INCOME_TYPE**: Income type - To add (encoded)
#
# **DAYS_EMPLOYED**: ok but days in years
#
# **AMT_INCOME_TOTAL**: Total Income - OK
#
# About the loan itself:
#
# **NAME_CONTRACT_TYPE**: Loan type - Replace 0 by cash loans and 1 by revolving loans
#
# **AMT_CREDIT**: Loan total amount - OK
#
# **AMT_ANNUITY**: Annuity - To add
#
# **AMT_GOODS_PRICE**: Goods total price - To add
#
# **NAME_HOUSING_TYPE**: Housing type - To add (encoded)

# %%
df_missing = application_test[['SK_ID_CURR', 'CODE_GENDER', 'NAME_FAMILY_STATUS',
                               'CNT_CHILDREN', 'NAME_EDUCATION_TYPE',
                               'NAME_INCOME_TYPE', 
                               'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_HOUSING_TYPE']]
df_missing.head(3)
# Out:
#    SK_ID_CURR CODE_GENDER NAME_FAMILY_STATUS  CNT_CHILDREN  \
# 0      100001           F            Married             0
# 1      100005           M            Married             0
# 2      100013           M            Married             0
#
#              NAME_EDUCATION_TYPE NAME_INCOME_TYPE  AMT_ANNUITY  \
# 0               Higher education          Working      20560.5
# 1  Secondary / secondary special          Working      17370.0
# 2               Higher education          Working      69777.0
#
#    AMT_GOODS_PRICE  NAME_HOUSING_TYPE
# 0         450000.0  House / apartment
# 1         180000.0  House / apartment
# 2         630000.0  House / apartment

# %%
df_missing_tr = application_train[['SK_ID_CURR', 'CODE_GENDER', 'NAME_FAMILY_STATUS',
                               'CNT_CHILDREN', 'NAME_EDUCATION_TYPE',
                               'NAME_INCOME_TYPE', 
                               'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_HOUSING_TYPE']]
df_missing_tr.head(3)
# Out:
#    SK_ID_CURR CODE_GENDER    NAME_FAMILY_STATUS  CNT_CHILDREN  \
# 0      100002           M  Single / not married             0
# 1      100003           F               Married             0
# 2      100004           M  Single / not married             0
#
#              NAME_EDUCATION_TYPE NAME_INCOME_TYPE  AMT_ANNUITY  \
# 0  Secondary / secondary special          Working      24700.5
# 1               Higher education    State servant      35698.5
# 2  Secondary / secondary special          Working       6750.0
#
#    AMT_GOODS_PRICE  NAME_HOUSING_TYPE
# 0         351000.0  House / apartment
# 1        1129500.0  House / apartment
# 2         135000.0  House / apartment

# %%
dash_df = data_test_boruta.merge(df_missing, on='SK_ID_CURR', how='right')
dash_df.head(3)
# Out:
#    SK_ID_CURR  NAME_CONTRACT_TYPE  FLAG_OWN_CAR  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0      100001                   0             0          135000.0    568800.0
# 1      100005                   0             0           99000.0    222768.0
# 2      100013                   0             1          202500.0    663264.0
#
#    NAME_TYPE_SUITE  NAME_INCOME_TYPE_x  NAME_FAMILY_STATUS_x  \
# 0                0                   0                     1
# 1                0                   0                     1
# 2               -1                   0                     1
#
#    NAME_HOUSING_TYPE_x  REGION_POPULATION_RELATIVE  ...  \
# 0                    0                    0.018845  ...
# 1                    0                    0.035797  ...
# 2                    0                    0.019104  ...
#
#    BUREAU_ACTIVE_CREDIT_TO_INCOME_RATIO  CURRENT_TO_APPROVED_CREDIT_MIN_RATIO  \
# 0                              6.546875                              0.041809
# 1                              6.046875                              0.180298
# 2                              4.632812                              0.036530
#
#    CODE_GENDER  NAME_FAMILY_STATUS_y  CNT_CHILDREN  \
# 0            F               Married             0
# 1            M               Married             0
# 2            M               Married             0
#
#              NAME_EDUCATION_TYPE  NAME_INCOME_TYPE_y  AMT_ANNUITY  \
# 0               Higher education             Working      20560.5
# 1  Secondary / secondary special             Working      17370.0
# 2               Higher education             Working      69777.0
#
#    AMT_GOODS_PRICE  NAME_HOUSING_TYPE_y
# 0         450000.0    House / apartment
# 1         180000.0    House / apartment
# 2         630000.0    House / apartment
#
# [3 rows x 95 columns]

# %%
dashboard = data_train_boruta.merge(df_missing_tr, on='SK_ID_CURR', how='right')
dashboard.drop('TARGET', axis=1, inplace=True)
dashboard = dashboard.head(2000)
dashboard
# Out:
#       SK_ID_CURR  NAME_CONTRACT_TYPE  FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 0         100002                 0.0           0.0          202500.0
# 1         100003                 0.0           0.0          270000.0
# 2         100004                 1.0           1.0           67500.0
# 3         100006                 0.0           0.0          135000.0
# 4         100007                 0.0           0.0          121500.0
# ...          ...                 ...           ...               ...
# 1995      102337                 0.0           0.0           49500.0
# 1996      102338                 0.0           1.0          135000.0
# 1997      102339                 1.0           1.0          135000.0
# 1998      102341                 1.0           0.0          202500.0
# 1999      102343                 0.0           0.0          180000.0
#
#       AMT_CREDIT  NAME_TYPE_SUITE  NAME_INCOME_TYPE_x  NAME_FAMILY_STATUS_x  \
# 0       406597.5              0.0                 0.0                   0.0
# 1      1293502.5              1.0                 1.0                   1.0
# 2       135000.0              0.0                 0.0                   0.0
# 3       312682.5              0.0                 0.0                   2.0
# 4       513000.0              0.0                 0.0                   0.0
# ...          ...              ...                 ...                   ...
# 1995    130824.0              0.0                 3.0                   4.0
# 1996    254700.0              0.0                 0.0                   1.0
# 1997    202500.0              0.0                 0.0                   1.0
# 1998    337500.0              0.0                 0.0                   0.0
# 1999    810000.0              0.0                 0.0                   1.0
#
#       NAME_HOUSING_TYPE_x  REGION_POPULATION_RELATIVE  ...  \
# 0                     0.0                    0.018799  ...
# 1                     0.0                    0.003542  ...
# 2                     0.0                    0.010033  ...
# 3                     0.0                    0.008018  ...
# 4                     0.0                    0.028656  ...
# ...                   ...                         ...  ...
# 1995                  0.0                    0.010643  ...
# 1996                  0.0                    0.018631  ...
# 1997                  0.0                    0.003069  ...
# 1998                  0.0                    0.072510  ...
# 1999                  1.0                    0.008476  ...
#
#       BUREAU_ACTIVE_CREDIT_TO_INCOME_RATIO  \
# 0                                 2.380859
# 1                                 3.000000
# 2                                 4.390625
# 3                                 4.390625
# 4                                 4.390625
# ...                                    ...
# 1995                              4.390625
# 1996                              4.390625
# 1997                              4.390625
# 1998                              3.189453
# 1999                              7.906250
#
#       CURRENT_TO_APPROVED_CREDIT_MIN_RATIO  CODE_GENDER  NAME_FAMILY_STATUS_y  \
# 0                                 0.440430            M  Single / not married
# 1                                 0.052612            F               Married
# 2                                 0.148926            M  Single / not married
# 3                                 0.077454            F        Civil marriage
# 4                                 0.028488            M  Single / not married
# ...                                    ...          ...                   ...
# 1995                              0.571777            F             Separated
# 1996                              0.281250            M               Married
# 1997                              0.166138            F               Married
# 1998                              0.279785            F  Single / not married
# 1999                              0.111084            M               Married
#
#       CNT_CHILDREN            NAME_EDUCATION_TYPE  NAME_INCOME_TYPE_y  \
# 0                0  Secondary / secondary special             Working
# 1                0               Higher education       State servant
# 2                0  Secondary / secondary special             Working
# 3                0  Secondary / secondary special             Working
# 4                0  Secondary / secondary special             Working
# ...            ...                            ...                 ...
# 1995             0  Secondary / secondary special           Pensioner
# 1996             0  Secondary / secondary special             Working
# 1997             1               Higher education             Working
# 1998             2  Secondary / secondary special             Working
# 1999             1  Secondary / secondary special             Working
#
#       AMT_ANNUITY  AMT_GOODS_PRICE  NAME_HOUSING_TYPE_y
# 0         24700.5         351000.0    House / apartment
# 1         35698.5        1129500.0    House / apartment
# 2          6750.0         135000.0    House / apartment
# 3         29686.5         297000.0    House / apartment
# 4         21865.5         513000.0    House / apartment
# ...           ...              ...                  ...
# 1995       5062.5         103500.0    House / apartment
# 1996      17019.0         225000.0    House / apartment
# 1997      10125.0         202500.0    House / apartment
# 1998      16875.0         337500.0    House / apartment
# 1999      21496.5         810000.0     Rented apartment
#
# [2000 rows x 95 columns]

# %%
# Transform DAYS_BIRTH in positive years
dash_df['YEAR_BIRTH'] = \
    np.trunc(np.abs(dash_df['DAYS_BIRTH'] / 365)).astype('int8')
# Transform DAYS_EMPLOYED in positive years
dash_df['YEAR_EMPLOYED'] = \
    np.trunc(np.abs(dash_df['DAYS_EMPLOYED'] / 365)).astype('int8')
# Transform NAME_CONTRACT_TYPE : 0 = Cash Loans et 1 = Revolving Loans
dash_df['NAME_CONTRACT_TYPE'] = ['Cash Loans' if row == 0 else 'Revolving Loans'
                        for row in dash_df['NAME_CONTRACT_TYPE']] 
dash_df.drop(['NAME_INCOME_TYPE_x', 'NAME_FAMILY_STATUS_x', 'NAME_HOUSING_TYPE_x'], axis = 1, inplace=True)
dict = {'NAME_INCOME_TYPE_y': 'NAME_INCOME_TYPE',
        'NAME_FAMILY_STATUS_y': 'NAME_FAMILY_STATUS',
        'NAME_HOUSING_TYPE_y': 'NAME_HOUSING_TYPE'}
 
# call rename () method
dash_df.rename(columns=dict,
          inplace=True)
dash_df
# Out:
#        SK_ID_CURR NAME_CONTRACT_TYPE  FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 0          100001         Cash Loans             0          135000.0
# 1          100005         Cash Loans             0           99000.0
# 2          100013         Cash Loans             1          202500.0
# 3          100028         Cash Loans             0          315000.0
# 4          100038         Cash Loans             1          180000.0
# ...           ...                ...           ...               ...
# 48739      456221         Cash Loans             0          121500.0
# 48740      456222         Cash Loans             0          157500.0
# 48741      456223         Cash Loans             1          202500.0
# 48742      456224         Cash Loans             0          225000.0
# 48743      456250         Cash Loans             1          135000.0
#
#        AMT_CREDIT  NAME_TYPE_SUITE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# 0        568800.0                0                    0.018845      -19241
# 1        222768.0                0                    0.035797      -18064
# 2        663264.0               -1                    0.019104      -20038
# 3       1575000.0                0                    0.026398      -13976
# 4        625500.0                0                    0.010033      -13040
# ...           ...              ...                         ...         ...
# 48739    412560.0                0                    0.002043      -19970
# 48740    622413.0                0                    0.035797      -11186
# 48741    315000.0                0                    0.026398      -15922
# 48742    450000.0                1                    0.018845      -13968
# 48743    312768.0                0                    0.006630      -13962
#
#        DAYS_EMPLOYED  OCCUPATION_TYPE  ...  CODE_GENDER  NAME_FAMILY_STATUS  \
# 0            -2328.0               -1  ...            F             Married
# 1            -4468.0               13  ...            M             Married
# 2            -4456.0                4  ...            M             Married
# 3            -1866.0                5  ...            F             Married
# 4            -2192.0               -1  ...            M             Married
# ...              ...              ...  ...          ...                 ...
# 48739        -5168.0               -1  ...            F               Widow
# 48740        -1149.0                5  ...            F             Married
# 48741        -3036.0               -1  ...            F             Married
# 48742        -2732.0                3  ...            M             Married
# 48743         -633.0                1  ...            F             Married
#
#        CNT_CHILDREN            NAME_EDUCATION_TYPE      NAME_INCOME_TYPE  \
# 0                 0               Higher education               Working
# 1                 0  Secondary / secondary special               Working
# 2                 0               Higher education               Working
# 3                 2  Secondary / secondary special               Working
# 4                 1  Secondary / secondary special               Working
# ...             ...                            ...                   ...
# 48739             0  Secondary / secondary special               Working
# 48740             2  Secondary / secondary special  Commercial associate
# 48741             1  Secondary / secondary special  Commercial associate
# 48742             0               Higher education  Commercial associate
# 48743             0  Secondary / secondary special               Working
#
#        AMT_ANNUITY  AMT_GOODS_PRICE  NAME_HOUSING_TYPE  YEAR_BIRTH  \
# 0          20560.5         450000.0  House / apartment          52
# 1          17370.0         180000.0  House / apartment          49
# 2          69777.0         630000.0  House / apartment          54
# 3          49018.5        1575000.0  House / apartment          38
# 4          32067.0         625500.0  House / apartment          35
# ...            ...              ...                ...         ...
# 48739      17473.5         270000.0  House / apartment          54
# 48740      31909.5         495000.0  House / apartment          30
# 48741      33205.5         315000.0  House / apartment          43
# 48742      25128.0         450000.0  House / apartment          38
# 48743      24709.5         270000.0  House / apartment          38
#
#        YEAR_EMPLOYED
# 0                  6
# 1                 12
# 2                 12
# 3                  5
# 4                  6
# ...              ...
# 48739             14
# 48740              3
# 48741              8
# 48742              7
# 48743              1
#
# [48744 rows x 94 columns]

# %%
# Transform DAYS_BIRTH in positive years
dashboard['YEAR_BIRTH'] = \
    np.trunc(np.abs(dashboard['DAYS_BIRTH'] / 365)).astype('int8')
# Transform DAYS_EMPLOYED in positive years
dashboard['YEAR_EMPLOYED'] = \
    np.trunc(np.abs(dashboard['DAYS_EMPLOYED'] / 365)).astype('int8')
# Transform NAME_CONTRACT_TYPE : 0 = Cash Loans et 1 = Revolving Loans
dashboard['NAME_CONTRACT_TYPE'] = ['Cash Loans' if row == 0 else 'Revolving Loans'
                        for row in dashboard['NAME_CONTRACT_TYPE']] 
dashboard.drop(['NAME_INCOME_TYPE_x', 'NAME_FAMILY_STATUS_x', 'NAME_HOUSING_TYPE_x'], axis = 1, inplace=True)
dict = {'NAME_INCOME_TYPE_y': 'NAME_INCOME_TYPE',
        'NAME_FAMILY_STATUS_y': 'NAME_FAMILY_STATUS',
        'NAME_HOUSING_TYPE_y': 'NAME_HOUSING_TYPE'}
 
# call rename () method
dashboard.rename(columns=dict,
          inplace=True)
dashboard
# Out:
#       SK_ID_CURR NAME_CONTRACT_TYPE  FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 0         100002         Cash Loans           0.0          202500.0
# 1         100003         Cash Loans           0.0          270000.0
# 2         100004    Revolving Loans           1.0           67500.0
# 3         100006         Cash Loans           0.0          135000.0
# 4         100007         Cash Loans           0.0          121500.0
# ...          ...                ...           ...               ...
# 1995      102337         Cash Loans           0.0           49500.0
# 1996      102338         Cash Loans           1.0          135000.0
# 1997      102339    Revolving Loans           1.0          135000.0
# 1998      102341    Revolving Loans           0.0          202500.0
# 1999      102343         Cash Loans           0.0          180000.0
#
#       AMT_CREDIT  NAME_TYPE_SUITE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# 0       406597.5              0.0                    0.018799     -9461.0
# 1      1293502.5              1.0                    0.003542    -16765.0
# 2       135000.0              0.0                    0.010033    -19046.0
# 3       312682.5              0.0                    0.008018    -19005.0
# 4       513000.0              0.0                    0.028656    -19932.0
# ...          ...              ...                         ...         ...
# 1995    130824.0              0.0                    0.010643    -21713.0
# 1996    254700.0              0.0                    0.018631    -14209.0
# 1997    202500.0              0.0                    0.003069    -14744.0
# 1998    337500.0              0.0                    0.072510    -10100.0
# 1999    810000.0              0.0                    0.008476    -15957.0
#
#       DAYS_EMPLOYED  OCCUPATION_TYPE  ...  CODE_GENDER    NAME_FAMILY_STATUS  \
# 0            -637.0              0.0  ...            M  Single / not married
# 1           -1188.0              1.0  ...            F               Married
# 2            -225.0              0.0  ...            M  Single / not married
# 3           -3040.0              0.0  ...            F        Civil marriage
# 4           -3038.0              1.0  ...            M  Single / not married
# ...             ...              ...  ...          ...                   ...
# 1995        -1648.0             -1.0  ...            F             Separated
# 1996         -139.0             13.0  ...            M               Married
# 1997        -5752.0              1.0  ...            F               Married
# 1998        -3084.0             -1.0  ...            F  Single / not married
# 1999        -2270.0              4.0  ...            M               Married
#
#       CNT_CHILDREN            NAME_EDUCATION_TYPE  NAME_INCOME_TYPE  \
# 0                0  Secondary / secondary special           Working
# 1                0               Higher education     State servant
# 2                0  Secondary / secondary special           Working
# 3                0  Secondary / secondary special           Working
# 4                0  Secondary / secondary special           Working
# ...            ...                            ...               ...
# 1995             0  Secondary / secondary special         Pensioner
# 1996             0  Secondary / secondary special           Working
# 1997             1               Higher education           Working
# 1998             2  Secondary / secondary special           Working
# 1999             1  Secondary / secondary special           Working
#
#       AMT_ANNUITY  AMT_GOODS_PRICE  NAME_HOUSING_TYPE  YEAR_BIRTH  \
# 0         24700.5         351000.0  House / apartment          25
# 1         35698.5        1129500.0  House / apartment          45
# 2          6750.0         135000.0  House / apartment          52
# 3         29686.5         297000.0  House / apartment          52
# 4         21865.5         513000.0  House / apartment          54
# ...           ...              ...                ...         ...
# 1995       5062.5         103500.0  House / apartment          59
# 1996      17019.0         225000.0  House / apartment          38
# 1997      10125.0         202500.0  House / apartment          40
# 1998      16875.0         337500.0  House / apartment          27
# 1999      21496.5         810000.0   Rented apartment          43
#
#       YEAR_EMPLOYED
# 0                 1
# 1                 3
# 2                 0
# 3                 8
# 4                 8
# ...             ...
# 1995              4
# 1996              0
# 1997             15
# 1998              8
# 1999              6
#
# [2000 rows x 94 columns]

# %% [markdown]
# #### Gather basic information about the customer

# %%
# Dataframe creation 
df_customer_info = dash_df[['SK_ID_CURR', 'YEAR_BIRTH', 'CODE_GENDER',
                               'NAME_FAMILY_STATUS',
                               'CNT_CHILDREN', 'NAME_EDUCATION_TYPE',
                               'NAME_INCOME_TYPE', 'YEAR_EMPLOYED',
                               'AMT_INCOME_TOTAL']]
df_customer_info.head()
# Out:
#    SK_ID_CURR  YEAR_BIRTH CODE_GENDER NAME_FAMILY_STATUS  CNT_CHILDREN  \
# 0      100001          52           F            Married             0
# 1      100005          49           M            Married             0
# 2      100013          54           M            Married             0
# 3      100028          38           F            Married             2
# 4      100038          35           M            Married             1
#
#              NAME_EDUCATION_TYPE NAME_INCOME_TYPE  YEAR_EMPLOYED  \
# 0               Higher education          Working              6
# 1  Secondary / secondary special          Working             12
# 2               Higher education          Working             12
# 3  Secondary / secondary special          Working              5
# 4  Secondary / secondary special          Working              6
#
#    AMT_INCOME_TOTAL
# 0          135000.0
# 1           99000.0
# 2          202500.0
# 3          315000.0
# 4          180000.0

# %%
# Dataframe creation 
df_customer_info_tr = dashboard[['SK_ID_CURR', 'YEAR_BIRTH', 'CODE_GENDER',
                               'NAME_FAMILY_STATUS',
                               'CNT_CHILDREN', 'NAME_EDUCATION_TYPE',
                               'NAME_INCOME_TYPE', 'YEAR_EMPLOYED',
                               'AMT_INCOME_TOTAL']]
df_customer_info_tr.head()
# Out:
#    SK_ID_CURR  YEAR_BIRTH CODE_GENDER    NAME_FAMILY_STATUS  CNT_CHILDREN  \
# 0      100002          25           M  Single / not married             0
# 1      100003          45           F               Married             0
# 2      100004          52           M  Single / not married             0
# 3      100006          52           F        Civil marriage             0
# 4      100007          54           M  Single / not married             0
#
#              NAME_EDUCATION_TYPE NAME_INCOME_TYPE  YEAR_EMPLOYED  \
# 0  Secondary / secondary special          Working              1
# 1               Higher education    State servant              3
# 2  Secondary / secondary special          Working              0
# 3  Secondary / secondary special          Working              8
# 4  Secondary / secondary special          Working              8
#
#    AMT_INCOME_TOTAL
# 0          202500.0
# 1          270000.0
# 2           67500.0
# 3          135000.0
# 4          121500.0

# %%
df_customer_info = df_customer_info.rename(columns = {
     'YEAR_BIRTH' : 'Age (years)',
     'CODE_GENDER' : 'Gender',
     'NAME_FAMILY_STATUS' : 'Family Status',
     'CNT_CHILDREN' : 'Kids',
     'NAME_EDUCATION_TYPE' : 'Education',
     'NAME_INCOME_TYPE' : 'Income Type',
     'YEAR_EMPLOYED' : 'Years Employed',
     'AMT_INCOME_TOTAL' : 'Income ($)'})
df_customer_info.loc[df_customer_info['SK_ID_CURR'] == 100271]
# Out:
#     SK_ID_CURR  Age (years) Gender Family Status  Kids  \
# 36      100271           63      F       Married     0
#
#                         Education Income Type  Years Employed  Income ($)
# 36  Secondary / secondary special   Pensioner               4    270000.0

# %%
df_customer_info_tr = df_customer_info_tr.rename(columns = {
     'YEAR_BIRTH' : 'Age (years)',
     'CODE_GENDER' : 'Gender',
     'NAME_FAMILY_STATUS' : 'Family Status',
     'CNT_CHILDREN' : 'Kids',
     'NAME_EDUCATION_TYPE' : 'Education',
     'NAME_INCOME_TYPE' : 'Income Type',
     'YEAR_EMPLOYED' : 'Years Employed',
     'AMT_INCOME_TOTAL' : 'Income ($)'})
df_customer_info_tr.loc[df_customer_info_tr['SK_ID_CURR'] == 100002]
# Out:
#    SK_ID_CURR  Age (years) Gender         Family Status  Kids  \
# 0      100002           25      M  Single / not married     0
#
#                        Education Income Type  Years Employed  Income ($)
# 0  Secondary / secondary special     Working               1    202500.0

# %%
df_customer_info.head(2000).to_pickle('./df_customer_info.pkl')

# %%
df_customer_info_tr.to_pickle('./df_customer_info_tr.pkl')

# %% [markdown]
# #### Gather basic information about the loan customer is applying for

# %%
# Informations sur la demande prêt
df_customer_loan = dash_df[['SK_ID_CURR', 'NAME_CONTRACT_TYPE',
                            'AMT_CREDIT',
                            'AMT_ANNUITY', 'AMT_GOODS_PRICE',
                            'NAME_HOUSING_TYPE']]

# %%
df_customer_loan = df_customer_loan.rename(columns = {
     'NAME_CONTRACT_TYPE' : 'Loan Type',
     'AMT_CREDIT' : 'Loan amount ($)',
     'AMT_ANNUITY' : 'Annuity ($)',
     'AMT_GOODS_PRICE' : 'Goods price ($)',
     'NAME_HOUSING_TYPE' : 'Housing Type'})
df_customer_loan.loc[df_customer_loan['SK_ID_CURR'] == 100271]
# Out:
#     SK_ID_CURR   Loan Type  Loan amount ($)  Annuity ($)  Goods price ($)  \
# 36      100271  Cash Loans        1800000.0      98770.5        1800000.0
#
#          Housing Type
# 36  House / apartment

# %%
df_customer_loan.head(2000).to_pickle('./df_customer_loan.pkl')

# %%
data_test_ltd.to_pickle('./data_test_ltd.pkl')

# %%
data_train_ltd.to_pickle('./data_train_ltd.pkl')

# %% [markdown]
# #### Gather basic information about the loan customer is applying for

# %%
# Informations sur la demande prêt
df_customer_loan_tr = dashboard[['SK_ID_CURR', 'NAME_CONTRACT_TYPE',
                            'AMT_CREDIT',
                            'AMT_ANNUITY', 'AMT_GOODS_PRICE',
                            'NAME_HOUSING_TYPE']]

# %%
df_customer_loan_tr = df_customer_loan_tr.rename(columns = {
     'NAME_CONTRACT_TYPE' : 'Loan Type',
     'AMT_CREDIT' : 'Loan amount ($)',
     'AMT_ANNUITY' : 'Annuity ($)',
     'AMT_GOODS_PRICE' : 'Goods price ($)',
     'NAME_HOUSING_TYPE' : 'Housing Type'})
df_customer_loan_tr.loc[df_customer_loan_tr['SK_ID_CURR'] == 100002]
# Out:
#    SK_ID_CURR   Loan Type  Loan amount ($)  Annuity ($)  Goods price ($)  \
# 0      100002  Cash Loans         406597.5      24700.5         351000.0
#
#         Housing Type
# 0  House / apartment

# %%
df_customer_loan_tr.to_pickle('./df_customer_loan_tr.pkl')

# %%
data_test_ltd.to_pickle('./data_test_ltd.pkl')

# %% [markdown]
# ### Full set

# %%
# Copie du jeu de test
test = data_test_boruta.copy(deep=True)
# Sauvegarde des identifiants des clients inutiles aux prédictions
customers_id = test['SK_ID_CURR']
# Préparation de la matrice à soumettre aux prédictions 
X_test = test.drop('SK_ID_CURR', axis=1)

# %%
# Score des prédictions de probabiltés
y_proba = best_model.predict_proba(X_test)[:, 1]
# Customers predictions
# class 0 : Non defaulters, class 1 : Defaulters
y_pred = best_model.predict(X_test)
# Constitution du dataframe pour merge
df_score = pd.DataFrame({'SK_ID_CURR' : customers_id,
                         'PREDICTED_CLASS' : y_pred,
                         'CUSTOMER_SCORE' : y_proba,
                         'CUSTOMER_SCORE_%' : np.round(y_proba * 100, 1)})
df_score1 = df_score.sort_values(by='CUSTOMER_SCORE_%', ascending=False)
df_score1.head(50)
# Out:
#         SK_ID_CURR  PREDICTED_CLASS  CUSTOMER_SCORE  CUSTOMER_SCORE_%
# 333823      291592              1.0        0.802025              80.2
# 317153      170148              1.0        0.789027              78.9
# 330321      265895              1.0        0.763154              76.3
# 334930      300137              1.0        0.755004              75.5
# 307580      100568              1.0        0.749763              75.0
# 323571      215910              1.0        0.741322              74.1
# 338538      325553              1.0        0.736372              73.6
# 333360      288138              1.0        0.733554              73.4
# 313796      146090              1.0        0.728786              72.9
# 351538      421386              1.0        0.723730              72.4
# 353507      436219              1.0        0.719057              71.9
# 354206      441297              1.0        0.716318              71.6
# 335110      301331              1.0        0.716448              71.6
# 326254      236266              1.0        0.682514              68.3
# 313323      142590              1.0        0.680898              68.1
# 316371      164766              1.0        0.681091              68.1
# 352931      432446              1.0        0.676980              67.7
# 308504      106854              1.0        0.674048              67.4
# 344352      369740              1.0        0.660430              66.0
# 318033      176483              1.0        0.654335              65.4
# 352464      429356              1.0        0.651225              65.1
# 326067      234809              1.0        0.647998              64.8
# 317397      171780              1.0        0.636149              63.6
# 310639      121997              1.0        0.627394              62.7
# 308646      108045              1.0        0.626114              62.6
# 336998      314761              1.0        0.624736              62.5
# 346058      383433              1.0        0.623517              62.4
# 328125      249559              1.0        0.624291              62.4
# 328329      251073              1.0        0.623399              62.3
# 310606      121772              1.0        0.622108              62.2
# 341275      346379              1.0        0.618403              61.8
# 342980      359673              1.0        0.613966              61.4
# 343526      363551              1.0        0.613511              61.4
# 340529      340610              1.0        0.612609              61.3
# 336752      313099              1.0        0.611138              61.1
# 320720      195937              1.0        0.609158              60.9
# 355011      447228              1.0        0.607945              60.8
# 339960      336156              1.0        0.606519              60.7
# 326599      238712              1.0        0.605167              60.5
# 334489      296744              1.0        0.604444              60.4
# 325744      232428              1.0        0.603337              60.3
# 324167      220416              1.0        0.598441              59.8
# 324403      222296              1.0        0.597463              59.7
# 327061      242231              1.0        0.597488              59.7
# 309968      117216              1.0        0.587667              58.8
# 319093      184226              1.0        0.586572              58.7
# 314750      152964              1.0        0.587404              58.7
# 316722      167152              1.0        0.578762              57.9
# 350662      414166              1.0        0.578995              57.9
# 316152      163188              1.0        0.577674              57.8

# %%
df_score.loc[df_score['SK_ID_CURR'] == 100038]
# Out:
#         SK_ID_CURR  PREDICTED_CLASS  CUSTOMER_SCORE  CUSTOMER_SCORE_%
# 307510      100038              0.0        0.087572               8.8

# %%
df_score['PREDICTED_CLASS'].value_counts()
# Out:
# 0.0    48606
# 1.0      138
# Name: PREDICTED_CLASS, dtype: int64

# %%
# Ajout des prédictions au dataframe du jeu de test
dash_df = df_score.merge(test, on='SK_ID_CURR', how='left')
dash_df
# Out:
#        SK_ID_CURR  PREDICTED_CLASS  CUSTOMER_SCORE  CUSTOMER_SCORE_%  \
# 0          100001              0.0        0.011471               1.1
# 1          100005              0.0        0.072649               7.3
# 2          100013              0.0        0.051149               5.1
# 3          100028              0.0        0.148063              14.8
# 4          100038              0.0        0.087572               8.8
# ...           ...              ...             ...               ...
# 48739      456221              0.0        0.017779               1.8
# 48740      456222              0.0        0.036961               3.7
# 48741      456223              0.0        0.012649               1.3
# 48742      456224              0.0        0.006910               0.7
# 48743      456250              0.0        0.231684              23.2
#
#        NAME_CONTRACT_TYPE  FLAG_OWN_CAR  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 0                       0             0          135000.0    568800.0
# 1                       0             0           99000.0    222768.0
# 2                       0             1          202500.0    663264.0
# 3                       0             0          315000.0   1575000.0
# 4                       0             1          180000.0    625500.0
# ...                   ...           ...               ...         ...
# 48739                   0             0          121500.0    412560.0
# 48740                   0             0          157500.0    622413.0
# 48741                   0             1          202500.0    315000.0
# 48742                   0             0          225000.0    450000.0
# 48743                   0             1          135000.0    312768.0
#
#        NAME_TYPE_SUITE  NAME_INCOME_TYPE  ...  INS_DBD_MEAN  \
# 0                    0                 0  ...      8.859375
# 1                    0                 0  ...     23.671875
# 2                   -1                 0  ...      5.722656
# 3                    0                 0  ...      3.265625
# 4                    0                 0  ...     12.250000
# ...                ...               ...  ...           ...
# 48739                0                 0  ...      7.332031
# 48740                0                 2  ...      6.000000
# 48741                0                 2  ...     31.625000
# 48742                1                 2  ...      7.277344
# 48743                0                 0  ...      8.601562
#
#        INS_LATE_PAYMENT_SUM  INS_36M_DAYS_ENTRY_PAYMENT_MIN  \
# 0                       4.0                          -840.0
# 1                       8.0                          -736.0
# 2                      49.0                         -2704.0
# 3                      55.0                         -1302.0
# 4                      12.0                          -802.0
# ...                     ...                             ...
# 48739                   3.0                          -661.0
# 48740                  62.0                          -815.0
# 48741                   8.0                          -818.0
# 48742                  26.0                          -559.0
# 48743                  32.0                         -1052.0
#
#        INS_36M_AMT_INSTALMENT_MEAN  INS_36M_AMT_PAYMENT_SUM  \
# 0                     15708.870117             3.499691e+05
# 1                      6240.205078             5.616184e+04
# 2                     11124.233398             1.444700e+06
# 3                      4730.878418             3.506999e+05
# 4                     11100.337891             1.332040e+05
# ...                            ...                      ...
# 48739                 91036.453125             2.731094e+05
# 48740                 10101.311523             4.803925e+05
# 48741                 23158.992188             1.852719e+05
# 48742                 23451.705078             4.455824e+05
# 48743                 13238.063477             6.522492e+05
#
#        INS_36M_SIGNIFICANT_LATE_PAYMENT_MEAN  INS_60M_LATE_PAYMENT_MEAN  \
# 0                                   0.910645                   1.000000
# 1                                   0.888672                   0.888672
# 2                                   0.226074                   0.316162
# 3                                   0.348389                   0.486816
# 4                                   1.000000                   1.000000
# ...                                      ...                        ...
# 48739                               1.000000                   1.000000
# 48740                               0.836914                   0.836914
# 48741                               1.000000                   1.000000
# 48742                               1.000000                   1.000000
# 48743                               0.640137                   0.640137
#
#        INS_60M_SIGNIFICANT_LATE_PAYMENT_MEAN  \
# 0                                   1.000000
# 1                                   0.888672
# 2                                   0.270996
# 3                                   0.486816
# 4                                   1.000000
# ...                                      ...
# 48739                               1.000000
# 48740                               0.836914
# 48741                               1.000000
# 48742                               1.000000
# 48743                               0.640137
#
#        BUREAU_ACTIVE_CREDIT_TO_INCOME_RATIO  \
# 0                                  6.546875
# 1                                  6.046875
# 2                                  4.632812
# 3                                  2.746094
# 4                                  4.632812
# ...                                     ...
# 48739                              6.898438
# 48740                              4.632812
# 48741                              0.249634
# 48742                              9.625000
# 48743                             19.281250
#
#        CURRENT_TO_APPROVED_CREDIT_MIN_RATIO
# 0                                  0.041809
# 1                                  0.180298
# 2                                  0.036530
# 3                                  0.037781
# 4                                  0.148071
# ...                                     ...
# 48739                              0.617188
# 48740                              0.043030
# 48741                              0.353271
# 48742                              0.089905
# 48743                              0.211304
#
# [48744 rows x 90 columns]

# %% [markdown]
# ### Limited set

# %%
# Copie du jeu de test
test_ltd = data_test_ltd.copy(deep=True)
# Sauvegarde des identifiants des clients inutiles aux prédictions
customers_id_ltd = test_ltd['SK_ID_CURR']
# Préparation de la matrice à soumettre aux prédictions 
X_test_ltd = test_ltd.drop('SK_ID_CURR', axis=1)

# %%
# Score des prédictions de probabiltés
y_proba = best_model.predict_proba(X_test_ltd)[:, 1]
# Customers predictions
# class 0 : Non defaulters, class 1 : Defaulters
y_pred = best_model.predict(X_test_ltd)
y_pred = (y_proba > 0.1)
y_pred = np.multiply(y_pred, 1)
# Constitution du dataframe pour merge
df_score = pd.DataFrame({'SK_ID_CURR' : customers_id_ltd,
                         'PREDICTED_CLASS' : y_pred,
                         'CUSTOMER_SCORE' : y_proba,
                         'CUSTOMER_SCORE_%' : np.round(y_proba * 100, 1)})
df1 = df_score.sort_values(by='CUSTOMER_SCORE_%', ascending=False)
df1.head(130)
# Out:
#         SK_ID_CURR  PREDICTED_CLASS  CUSTOMER_SCORE  CUSTOMER_SCORE_%
# 307580      100568                1        0.749763              75.0
# 308504      106854                1        0.674048              67.4
# 308646      108045                1        0.626114              62.6
# 309307      112771                1        0.559066              55.9
# 308140      104410                1        0.556654              55.7
# ...            ...              ...             ...               ...
# 307891      102617                1        0.168785              16.9
# 309360      113087                1        0.167546              16.8
# 307721      101427                1        0.166850              16.7
# 308394      106116                1        0.167408              16.7
# 308876      109642                1        0.165848              16.6
#
# [130 rows x 4 columns]

# %%
df_score.loc[df_score['SK_ID_CURR'] == 100038]
# Out:
#         SK_ID_CURR  PREDICTED_CLASS  CUSTOMER_SCORE  CUSTOMER_SCORE_%
# 307510      100038                0        0.087572               8.8

# %%
df_score['PREDICTED_CLASS'].value_counts()
# Out:
# 0    1701
# 1     299
# Name: PREDICTED_CLASS, dtype: int64

# %% [markdown]
# ### Limited train set

# %%
# Copie du jeu de test
train_ltd = data_train_ltd.copy(deep=True)
# Sauvegarde des identifiants des clients inutiles aux prédictions
customers_id_ltd = train_ltd['SK_ID_CURR']
# Préparation de la matrice à soumettre aux prédictions 
X_train_ltd = train_ltd.drop('SK_ID_CURR', axis=1)

# %%
# Score des prédictions de probabiltés
y_proba = best_model.predict_proba(X_train_ltd)[:, 1]
# Customers predictions
# class 0 : Non defaulters, class 1 : Defaulters
y_pred = best_model.predict(X_train_ltd)
y_pred = (y_proba > 0.1)
y_pred = np.multiply(y_pred, 1)
# Constitution du dataframe pour merge
df_score_tr = pd.DataFrame({'SK_ID_CURR' : customers_id_ltd,
                         'PREDICTED_CLASS' : y_pred,
                         'CUSTOMER_SCORE' : y_proba,
                         'CUSTOMER_SCORE_%' : np.round(y_proba * 100, 1)})
df = df_score_tr.sort_values(by='CUSTOMER_SCORE_%', ascending=False)
df.head(500)
# Out:
#       SK_ID_CURR  PREDICTED_CLASS  CUSTOMER_SCORE  CUSTOMER_SCORE_%
# 211       100246                1        0.788699              78.9
# 560       100646                1        0.749247              74.9
# 726       100839                1        0.748287              74.8
# 695       100804                1        0.702962              70.3
# 344       100396                1        0.696607              69.7
# ...          ...              ...             ...               ...
# 998       101155                0        0.091928               9.2
# 1646      101931                0        0.090518               9.1
# 580       100666                0        0.091121               9.1
# 1061      101232                0        0.091178               9.1
# 1325      101557                0        0.090681               9.1
#
# [500 rows x 4 columns]

# %%
df_score_tr.loc[df_score_tr['SK_ID_CURR'] == 100804]
# Out:
#      SK_ID_CURR  PREDICTED_CLASS  CUSTOMER_SCORE  CUSTOMER_SCORE_%
# 695      100804                1        0.702962              70.3

# %%
df_score_tr['PREDICTED_CLASS'].value_counts()
# Out:
# 0    1548
# 1     452
# Name: PREDICTED_CLASS, dtype: int64

# %%
# Test set sans l'identifiant
X_train_ltd = data_train_ltd.set_index('SK_ID_CURR')
# Entraînement de shap sur le train set
shap_explainer = shap.Explainer(best_model, X_train_ltd)
shap_values_tr_ltd = shap_explainer(X_train_ltd, check_additivity=False)
# Out:
# 100%|===================| 1999/2000 [22:59<00:00]

# %%
pickle.dump(shap_values_tr_ltd, open('shap_values_tr_ltd.pkl', 'wb'))

# %% [markdown]
# *************************************

# %%
def explain(customer_id):  
    
    explainer = shap.TreeExplainer(best_model)
    X_shap = test.set_index('SK_ID_CURR')
    X_test_cur = X_shap.loc[[customer_id]]
    X_test_cur_array = X_test_cur.values.reshape(1, -1)

    shap_values_cur = explainer.shap_values(X_test_cur_array)
    exp_val = explainer.expected_value[1]
    return exp_val

exp_val = explain(451379)
exp_val
# Out:
# -3.1573977065395495

# %%
pickle.dump(exp_val, open('exp_value.pkl', 'wb'))

# %% [markdown]
# ### Neighbours

# %%
data_test_boruta = pd.read_pickle("test_data_boruta.pkl")
data_test_boruta
# Out:
#         SK_ID_CURR  NAME_CONTRACT_TYPE  FLAG_OWN_CAR  AMT_INCOME_TOTAL  \
# 307506      100001                   0             0          135000.0
# 307507      100005                   0             0           99000.0
# 307508      100013                   0             1          202500.0
# 307509      100028                   0             0          315000.0
# 307510      100038                   0             1          180000.0
# ...            ...                 ...           ...               ...
# 356245      456221                   0             0          121500.0
# 356246      456222                   0             0          157500.0
# 356247      456223                   0             1          202500.0
# 356248      456224                   0             0          225000.0
# 356249      456250                   0             1          135000.0
#
#         AMT_CREDIT  NAME_TYPE_SUITE  NAME_INCOME_TYPE  NAME_FAMILY_STATUS  \
# 307506    568800.0                0                 0                   1
# 307507    222768.0                0                 0                   1
# 307508    663264.0               -1                 0                   1
# 307509   1575000.0                0                 0                   1
# 307510    625500.0                0                 0                   1
# ...            ...              ...               ...                 ...
# 356245    412560.0                0                 0                   3
# 356246    622413.0                0                 2                   1
# 356247    315000.0                0                 2                   1
# 356248    450000.0                1                 2                   1
# 356249    312768.0                0                 0                   1
#
#         NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  ...  INS_DBD_MEAN  \
# 307506                  0                    0.018845  ...      8.859375
# 307507                  0                    0.035797  ...     23.671875
# 307508                  0                    0.019104  ...      5.722656
# 307509                  0                    0.026398  ...      3.265625
# 307510                  0                    0.010033  ...     12.250000
# ...                   ...                         ...  ...           ...
# 356245                  0                    0.002043  ...      7.332031
# 356246                  0                    0.035797  ...      6.000000
# 356247                  0                    0.026398  ...     31.625000
# 356248                  0                    0.018845  ...      7.277344
# 356249                  0                    0.006630  ...      8.601562
#
#         INS_LATE_PAYMENT_SUM  INS_36M_DAYS_ENTRY_PAYMENT_MIN  \
# 307506                   4.0                          -840.0
# 307507                   8.0                          -736.0
# 307508                  49.0                         -2704.0
# 307509                  55.0                         -1302.0
# 307510                  12.0                          -802.0
# ...                      ...                             ...
# 356245                   3.0                          -661.0
# 356246                  62.0                          -815.0
# 356247                   8.0                          -818.0
# 356248                  26.0                          -559.0
# 356249                  32.0                         -1052.0
#
#         INS_36M_AMT_INSTALMENT_MEAN  INS_36M_AMT_PAYMENT_SUM  \
# 307506                 15708.870117             3.499691e+05
# 307507                  6240.205078             5.616184e+04
# 307508                 11124.233398             1.444700e+06
# 307509                  4730.878418             3.506999e+05
# 307510                 11100.337891             1.332040e+05
# ...                             ...                      ...
# 356245                 91036.453125             2.731094e+05
# 356246                 10101.311523             4.803925e+05
# 356247                 23158.992188             1.852719e+05
# 356248                 23451.705078             4.455824e+05
# 356249                 13238.063477             6.522492e+05
#
#         INS_36M_SIGNIFICANT_LATE_PAYMENT_MEAN  INS_60M_LATE_PAYMENT_MEAN  \
# 307506                               0.910645                   1.000000
# 307507                               0.888672                   0.888672
# 307508                               0.226074                   0.316162
# 307509                               0.348389                   0.486816
# 307510                               1.000000                   1.000000
# ...                                       ...                        ...
# 356245                               1.000000                   1.000000
# 356246                               0.836914                   0.836914
# 356247                               1.000000                   1.000000
# 356248                               1.000000                   1.000000
# 356249                               0.640137                   0.640137
#
#         INS_60M_SIGNIFICANT_LATE_PAYMENT_MEAN  \
# 307506                               1.000000
# 307507                               0.888672
# 307508                               0.270996
# 307509                               0.486816
# 307510                               1.000000
# ...                                       ...
# 356245                               1.000000
# 356246                               0.836914
# 356247                               1.000000
# 356248                               1.000000
# 356249                               0.640137
#
#         BUREAU_ACTIVE_CREDIT_TO_INCOME_RATIO  \
# 307506                              6.546875
# 307507                              6.046875
# 307508                              4.632812
# 307509                              2.746094
# 307510                              4.632812
# ...                                      ...
# 356245                              6.898438
# 356246                              4.632812
# 356247                              0.249634
# 356248                              9.625000
# 356249                             19.281250
#
#         CURRENT_TO_APPROVED_CREDIT_MIN_RATIO
# 307506                              0.041809
# 307507                              0.180298
# 307508                              0.036530
# 307509                              0.037781
# 307510                              0.148071
# ...                                      ...
# 356245                              0.617188
# 356246                              0.043030
# 356247                              0.353271
# 356248                              0.089905
# 356249                              0.211304
#
# [48744 rows x 87 columns]

# %%
most_imp_feat = ['INS_60M_SIGNIFICANT_LATE_PAYMENT_MEAN',
            'EXT_SOURCES_NANMEDIAN',
            'INS_36M_AMT_PAYMENT_SUM',
            'EXT_SOURCES_MIN',
            'INS_60M_LATE_PAYMENT_MEAN',
            'EXT_SOURCES_MAX',
            'CREDIT_TO_ANNUITY_RATIO',
            'ANNUITY_TO_INCOME_RATIO',
            'BUREAU_CONSUMER_DAYS_CREDIT_ENDDATE_MAX',
            'BUREAU_ACTIVE_DAYS_CREDIT_UPDATE_MEAN',
                 
            'ID_TO_BIRTH_RATIO',
            'DAYS_BIRTH',
            'AMT_CREDIT',
            'PREV_DAYS_DECISION_MEAN',
            'INS_DBD_MEAN',
            'PREV_Consumer_AMT_CREDIT_SUM',
            'PHONE_TO_BIRTH_RATIO',
            'INCOME_TO_BIRTH_RATIO',
            'CURRENT_TO_APPROVED_CREDIT_MIN_RATIO',
            'APPROVED_CREDIT_TO_ANNUITY_RATIO_MEAN']

# %%
X_test = data_test_boruta[most_imp_feat]

# %%
X_train = data_train_boruta[most_imp_feat]

# %%
# Standardization for KNN - test set
scaler = StandardScaler()
X_test_std = scaler.fit_transform(X_test)
X_test_std = pd.DataFrame(X_test_std, index=X_test.index, columns=X_test.columns.to_list())
X_test_std.shape
# Out:
# (48744, 20)

# %%
# Standardization for KNN - train set
scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_train_std = pd.DataFrame(X_train_std, index=X_train.index, columns=X_train.columns.to_list())
X_train_std.shape
# Out:
# (307506, 20)

# %%
dash_df.shape
# Out:
# (48744, 90)

# %%
y_test = dash_df['CUSTOMER_SCORE'].astype('int64')
y_test.shape
# Out:
# (48744,)

# %%
y_train = dash_df['CUSTOMER_SCORE'].astype('int64')
y_train.shape
# Out:
# (307506,)

# %%
# Model initialization
knn_test = KNeighborsClassifier(10, n_jobs = -1)
# Model training
knn_test.fit(X_test_std, y_test)
# Out:
# KNeighborsClassifier(n_jobs=-1, n_neighbors=10)

# %%
# Index of the 10 nearest neighbors
index_10_neigh_test = knn_test.kneighbors(X_test_std)[1]
dash_df['INDEX_10_NEIGH_MEAN'] = \
    [index for index in index_10_neigh_test]

# %%
# Score of the 10 nearest neighbors
dash_df['INDEX_10_NEIGH_MEAN'] = \
    [dash_df['CUSTOMER_SCORE'].iloc[index].mean()
     for index in index_10_neigh_test]

# %%
# dataframe reconstitution
dash_df['10_NEIGH_MEAN_SCORE'] = \
    [dash_df['CUSTOMER_SCORE'].iloc[index].mean()
     for index in index_10_neigh_test]

# %%
df2 = dash_df.sort_values(by='10_NEIGH_MEAN_SCORE', ascending=False)
df2.head(100)
# Out:
#        SK_ID_CURR  PREDICTED_CLASS  CUSTOMER_SCORE  CUSTOMER_SCORE_%  \
# 21153      253499              1.0        0.515717              51.6
# 31036      325590              0.0        0.398855              39.9
# 74         100568              1.0        0.749763              75.0
# 26317      291592              1.0        0.802025              80.2
# 25093      282773              0.0        0.435266              43.5
# ...           ...              ...             ...               ...
# 33023      340610              1.0        0.612609              61.3
# 4543       132485              0.0        0.141607              14.2
# 13449      197529              0.0        0.329246              32.9
# 33544      344762              0.0        0.144531              14.5
# 30359      320765              0.0        0.156825              15.7
#
#        NAME_CONTRACT_TYPE  FLAG_OWN_CAR  AMT_INCOME_TOTAL  AMT_CREDIT  \
# 21153                   0             1          184500.0    517500.0
# 31036                   0             0          292500.0    601470.0
# 74                      0             0          112500.0    312768.0
# 26317                   0             0          112500.0    234369.0
# 25093                   0             0          135000.0    573408.0
# ...                   ...           ...               ...         ...
# 33023                   0             1           90000.0    552555.0
# 4543                    0             1          135000.0    594121.5
# 13449                   0             1           90000.0    358344.0
# 33544                   0             1           76500.0    315000.0
# 30359                   0             0          112500.0    439074.0
#
#        NAME_TYPE_SUITE  NAME_INCOME_TYPE  ...  INS_36M_DAYS_ENTRY_PAYMENT_MIN  \
# 21153                0                 0  ...                          -816.0
# 31036                0                 0  ...                         -1223.0
# 74                   0                 0  ...                          -749.0
# 26317                0                 0  ...                          -437.0
# 25093                0                 0  ...                          -269.0
# ...                ...               ...  ...                             ...
# 33023                0                 0  ...                          -532.0
# 4543                 0                 0  ...                         -2912.0
# 13449                0                 1  ...                          -739.0
# 33544                0                 0  ...                          -992.0
# 30359                0                 1  ...                          -215.0
#
#        INS_36M_AMT_INSTALMENT_MEAN  INS_36M_AMT_PAYMENT_SUM  \
# 21153                 62932.746094             2.517310e+05
# 31036                 63645.203125             1.077283e+06
# 74                     8640.897461             1.555362e+05
# 26317                  5181.911621             8.317989e+04
# 25093                  6100.830078             2.440332e+04
# ...                            ...                      ...
# 33023                  7289.818848             2.624335e+05
# 4543                   2306.529785             2.861909e+05
# 13449                 11224.202148             1.010089e+06
# 33544                 12282.608398             1.171168e+05
# 30359                 10000.338867             8.000271e+04
#
#        INS_36M_SIGNIFICANT_LATE_PAYMENT_MEAN  INS_60M_LATE_PAYMENT_MEAN  \
# 21153                               1.000000                   1.000000
# 31036                               0.625000                   0.687500
# 74                                  1.000000                   1.000000
# 26317                               0.882324                   0.941406
# 25093                               1.000000                   1.000000
# ...                                      ...                        ...
# 33023                               0.416748                   0.416748
# 4543                                0.291992                   0.291992
# 13449                               0.539551                   0.565918
# 33544                               0.000000                   0.500000
# 30359                               0.375000                   0.375000
#
#        INS_60M_SIGNIFICANT_LATE_PAYMENT_MEAN  \
# 21153                               1.000000
# 31036                               0.625000
# 74                                  1.000000
# 26317                               0.882324
# 25093                               1.000000
# ...                                      ...
# 33023                               0.416748
# 4543                                0.291992
# 13449                               0.539551
# 33544                               0.227295
# 30359                               0.375000
#
#        BUREAU_ACTIVE_CREDIT_TO_INCOME_RATIO  \
# 21153                              7.714844
# 31036                              4.632812
# 74                                 4.960938
# 26317                              0.749512
# 25093                             19.703125
# ...                                     ...
# 33023                              1.250000
# 4543                               4.632812
# 13449                              5.800781
# 33544                              4.632812
# 30359                              4.632812
#
#        CURRENT_TO_APPROVED_CREDIT_MIN_RATIO  INDEX_10_NEIGH_MEAN  \
# 21153                              0.137085             0.420394
# 31036                              0.393066             0.394981
# 74                                 0.170410             0.382799
# 26317                              0.148438             0.382691
# 25093                              0.040680             0.381508
# ...                                     ...                  ...
# 33023                              0.028641             0.281482
# 4543                               0.064880             0.281144
# 13449                              0.047333             0.281030
# 33544                              0.122009             0.280905
# 30359                              0.161255             0.280710
#
#        10_NEIGH_MEAN_SCORE
# 21153             0.420394
# 31036             0.394981
# 74                0.382799
# 26317             0.382691
# 25093             0.381508
# ...                    ...
# 33023             0.281482
# 4543              0.281144
# 13449             0.281030
# 33544             0.280905
# 30359             0.280710
#
# [100 rows x 92 columns]

# %%
# customer score 
customer_id = 344762
customer_score = int(np.rint(dash_df[dash_df['SK_ID_CURR'] == customer_id]['CUSTOMER_SCORE_%']))
customer_score
# Out:
# 14

# %%
# Score du client en pourcentage?
customer_id = 344762
mean_neigh_score = int(np.rint(dash_df[dash_df['SK_ID_CURR'] == customer_id]['10_NEIGH_MEAN_SCORE'] * 100))
mean_neigh_score
# Out:
# 28

# %%
pickle.dump(dash_df, open('dash_df.pkl', 'wb'))
